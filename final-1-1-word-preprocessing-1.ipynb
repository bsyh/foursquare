# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer

from geopy.geocoders import Nominatim

import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import PorterStemmer, WordNetLemmatizer

import Levenshtein as lev
import math
from collections import Counter

from pickle import dump, load
import time
from sklearn.neighbors import BallTree


import itertools
from tqdm.auto import tqdm
tqdm.pandas()
import gc

from fuzzywuzzy import fuzz
#!pip install -U sentence_transformers
#from sentence_transformers import SentenceTransformer, util
#from sentence_transformers.cross_encoder import CrossEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from keras.preprocessing import text, sequence
from scipy import spatial

from sklearn.metrics.pairwise import cosine_similarity

# %%
start_time = time.time()
folds = 10

# %%
word_cols = ['name_1','name_2','address_1','address_2','url_1','url_2','categories_1','categories_2']
col_1 = ['name_1','address_1','categories_1','url_1']
col_2 = ['name_2','address_2','categories_2','url_2']

# %%
def fuzzy_similarity(df, cols_1, cols_2):
    # length for cols_1 and cols_2 must be the same.
    for i in tqdm(range(len(cols_1))):
        df[f"{cols_1[i]}_fuzzy"] = df.progress_apply(lambda x: lev.ratio(x[cols_1[i]],x[cols_2[i]]), axis = 1)
        df[f"{cols_1[i]}_fuzzy_partial"] = df.progress_apply(lambda x: fuzz.partial_ratio(x[cols_1[i]],x[cols_2[i]]), axis = 1)
        gc.collect()
    return df

# %%
for i in tqdm(range(folds)):
    gc.collect()
    pairs = pd.read_pickle(f"../input/fourpoints-text-words-parts/train_pairs_words_{i}.pkl")
    pairs = fuzzy_similarity(pairs, col_1, col_2)
    pairs.drop(word_cols, axis=1, inplace = True)
    pairs.to_pickle(f"./train_pairs_words_new_{i}.pkl")
    del pairs
    gc.collect()
# Out:
# ...
#   0%|          | 0/1710745 [00:00<?, ?it/s]

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 3643.6299023628235 seconds ---

# %% [markdown]
# <a href="./train_pairs_words_new_0.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_1.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_2.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_3.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_4.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_5.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_6.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_7.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_8.pkl"> train_pairs pickle </a>
#
# <a href="./train_pairs_words_new_9.pkl"> train_pairs pickle </a>
